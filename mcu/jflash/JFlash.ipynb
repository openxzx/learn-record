# %% [markdown]
# # JFlash burn firmware
#
#     We can use the JFlash tools for STM32 executable file, eg. hex files.

# %%
from IPython.display import Image
Image(filename='jflash1.png', width=1200, height=1200)

# %%
from IPython.display import Image
Image(filename='jflash2.png', width=600, height=600)

# %%
from IPython.display import Image
Image(filename='jflash3.png', width=600, height=600)

# %% [markdown]
# Programming executable file, program will run.
