# %% [markdown]
# # Keil MDK
#
#     When we are developing the STM32, we could use the Keil MDK tools for STM32's debug.
#
#     Keil MDK is an IDE tools for the sofeware debugging, Debug mode setting for the above.
#
#     C/C++ option add DEBUG_MAC which must need for inline debugging.

# %%
from IPython.display import Image
Image(filename='./keil3.png', width=600, height=600)

# %%
from IPython.display import Image
Image(filename='./keil1.png', width=600, height=600)

# %%
from IPython.display import Image
Image(filename='./keil2.png', width=600, height=600)
