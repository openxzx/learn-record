# %% [markdown]
# # C/Python设置字体输出
#
#     在软件开发过程中，有时候为了更好的对输出信息的不同部分方便的查看，这里使用不同的字体颜色和背景色来做区分。

# %%
from IPython.display import Image
Image(filename='../images/font-color.png', width=1000, height=1000)

# %%
print("\033[0;31mhello world!\033[0m")
# Out:
# hello world!

# %%
print("\033[0;31;46mhello world!\033[0m")
# Out:
# hello world!

# %%
print("\033[4;32mhello world!\033[0m")
# Out:
# hello world!

# %%
print("\033[7;30;41mhello world!\033[0m")
# Out:
# hello world!

# %%
print("\033[1;31;46mhello world!\033[0m")
# Out:
# hello world!
