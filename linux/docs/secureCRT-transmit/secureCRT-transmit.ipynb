# %% [markdown]
# # Using secureCRT transmit file into linux system
#
#     In fact, i used secureCRT tools to transmitting zip's files into Raspberry.

# %%
from IPython.display import Image
Image(filename='secureCRT1.png', width=650, height=600)

# %%
from IPython.display import Image
Image(filename='secureCRT2.png', width=650, height=600)

# %% [markdown]
# ## unzip command
#
#     In fact, transmitting file format is .zip, we need to uncompress zip format file.
#
#     unzip test.zip
