# %% [markdown]
# # Tftp32 burning the image file
#
#     We could make the system into a bad status. We can not enter into the line command.
#     So we can use tftp32 tools which burn the image file.

# %% [markdown]
# ## Step

# %% [markdown]
# ### Reboot system
#
#     Rebooting system and selecting '2', making the system enter into tftp32 tools burning for image file.
#
#     Then setting your computer IP and board are the same session.

# %%
from IPython.display import Image
Image(filename='tftp1.png', width=650, height=600)

# %%
from IPython.display import Image
Image(filename='tftp2.png', width=650, height=600)

# %% [markdown]
# ### Burning image file
#
#     Inputting image file name into the correct location, then pressing the enter key and burning done.

# %%
from IPython.display import Image
Image(filename='tftp3.png', width=650, height=600)

# %%
from IPython.display import Image
Image(filename='tftp4.png', width=650, height=600)
