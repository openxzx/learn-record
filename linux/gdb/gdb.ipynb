# %% [markdown]
# # gdb调试的基本使用
#
#     在使用gcc编译代码的时候，使用-g参数编译出来的可执行文件就包含了调试信息，并使用gdb exec_file进入到gdb交互式调试。

# %% [markdown]
# ## gdb调试命令

# %%
from IPython.display import Image
Image(filename='../images/gdb.png', width=800, height=600)
